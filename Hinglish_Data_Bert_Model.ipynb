# %% [markdown]
# # Unzip the data

# %%
# !unzip 'data.zip'
# Out:
# Archive:  data.zip
# replace data/hinglish_stopwords.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data/hinglish_stopwords.txt
#   inflating: data/test/Hindi_test_unalbelled_conll_updated.txt
#   inflating: data/test/test_labels_hinglish.txt
#   inflating: data/train/dev_3k_split_conll.txt
#   inflating: data/train/train_14k_split_conll.txt
#   inflating: data/train/train_conll.txt
#   inflating: data/train/trial_conll.txt

# %%
# !pip install ktrain
# Out:
# Requirement already satisfied: ktrain in /usr/local/lib/python3.10/dist-packages (0.37.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (3.7.1)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.5.3)
# Requirement already satisfied: fastprogress>=0.1.21 in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.27.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ktrain) (23.1)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.0.9)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.42.1)
# Requirement already satisfied: cchardet in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.1.7)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from ktrain) (4.0.0)
# Requirement already satisfied: syntok>1.3.3 in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.4.4)
# Requirement already satisfied: tika in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.6.0)
# Requirement already satisfied: transformers>=4.17.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (4.30.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.1.99)
# Requirement already satisfied: keras-bert>=0.86.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.89.0)
# Requirement already satisfied: whoosh in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.7.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-bert>=0.86.0->ktrain) (1.22.4)
# Requirement already satisfied: keras-transformer==0.40.0 in /usr/local/lib/python3.10/dist-packages (from keras-bert>=0.86.0->ktrain) (0.40.0)
# Requirement already satisfied: keras-pos-embd==0.13.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.13.0)
# Requirement already satisfied: keras-multi-head==0.29.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.29.0)
# Requirement already satisfied: keras-layer-normalization==0.16.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.16.0)
# Requirement already satisfied: keras-position-wise-feed-forward==0.8.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.8.0)
# Requirement already satisfied: keras-embed-sim==0.10.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.10.0)
# Requirement already satisfied: keras-self-attention==0.51.0 in /usr/local/lib/python3.10/dist-packages (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.51.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->ktrain) (2022.7.1)
# Requirement already satisfied: regex>2016 in /usr/local/lib/python3.10/dist-packages (from syntok>1.3.3->ktrain) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (0.16.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (4.65.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (3.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika->ktrain) (67.7.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=4.17.0->ktrain) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=4.17.0->ktrain) (4.6.3)

# %% [markdown]
# # Imports

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import numpy as np
from matplotlib import pyplot as plt
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
from nltk import download
download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Defining Tweet Class

# %%
class Tweet:
    def __init__(self):
        self.uid = None
        self.content = ''
        self.sentiment = ''

# %% [markdown]
# # Definining Methods for Data Loading and Cleaning

# %%
def cleanTweet(tweet):
#     print(tweet.content,"\n")
#     tweet.content = re.sub(r'@ [0-9a-zA-Z]+', '', tweet.content) # remove @ mentions
    tweet.content = re.sub(r'\_', '', tweet.content) # remove underscores
    tweet.content = re.sub(r'…', '', tweet.content) # remove elipses/dots
    tweet.content = re.sub(r'\.', '', tweet.content) # remove elipses/dots
    tweet.content = re.sub(r'^RT[\s]+', '', tweet.content) # remove RT
    tweet.content = re.sub("[#@©àâ€¦¥°¤ð¹ÿœ¾¨‡†§‹²¿¸ˆ]", '', tweet.content) # remove weird symbols
    tweet.content = tweet.content.split("http")[0].split('https')[0] # remove http/https
    tweet.content = ''.join([i for i in tweet.content if not i.isdigit()]) # remove digits
    tweet.content = ''.join([word for word in tweet.content if word not in string.punctuation]) # remove punctuations
    tweet.content = TweetTokenizer(preserve_case=False, strip_handles=True,reduce_len=True).tokenize(tweet.content)
    tweet.content = ' '.join([i for i in tweet.content]) # convert to string
#     print(tweet.content)
#     print("============================================================================")
    return tweet

def load_stop_words():
    stopwords_english = stopwords.words('english')
    stopwords_hinglish = []
    with open('data/hinglish_stopwords.txt','r') as fp:
        while True:
            line = fp.readline()
            if not line:
                break
            stopwords_hinglish.append(line.strip())
    return stopwords_english, stopwords_hinglish

def readFile(filename, test_data=False):
    stemmer_english = PorterStemmer()
    stopwords_english, stopwords_hinglish = load_stop_words()
    all_tweets = []
    with open(filename, 'r', encoding="utf8") as fp:
        tweet = Tweet()
        last_one = False
        while True:
            line = fp.readline()
            if not line:
                last_one = True
            if len(line.split()) > 1 or last_one==True:
                if last_one==True or line.split()[0] == 'meta':
                    if len(tweet.content) > 0 or last_one==True:
                        all_tweets.append(cleanTweet(tweet))
                        if last_one==True:
                            break
                        tweet = Tweet()
                    tweet.uid = line.split()[1]
                    tweet.sentiment = line.split()[2] if test_data==False else None
                else:
                    if line.split()[1] == "Eng":
                        if line.split()[0] not in stopwords_english:
#                             line.split()[0] = autoCorrect(line.split()[0])
                            tweet.content += stemmer_english.stem(line.split()[0]) + " "
                    elif line.split()[1] == "Hin":
                        if line.split()[0] not in stopwords_hinglish:
                            tweet.content += line.split()[0] + " "
                    else:
                        tweet.content += line.split()[0] + " "
        return all_tweets

# %% [markdown]
# # Defining Method for Showing Results

# %%
def plot_confusion_matrix(cm,title='Confusion Matrix',cmap=plt.cm.Greens):
    import itertools
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    classes = ['neutral','positive','negative']
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

def show_results(y_test, y_pred):
    print("F1 Score: ", f1_score(y_test, y_pred, average="weighted"))
    print()
    cnf_matrix = confusion_matrix(y_test, y_pred, labels=[0,1,2])
    plot_confusion_matrix(cnf_matrix)

# %% [markdown]
# # ===================================================

# %% [markdown]
# # Mission Control - Training

# %% [markdown]
# ### Data Loading

# %%
# all_tweets = readFile(r'data\train\train_14k_split_conll.txt')
# all_tweets.extend(readFile(r'data\train\dev_3k_split_conll.txt'))
all_tweets = (readFile(r'data/train/train_conll.txt'))
# all_tweets = (readFile(r'data\train\trial_conll.txt'))

# %% [markdown]
# ### ktrain Stuff

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"]="0";

# %%
import ktrain
from ktrain import text

# %%
x_train = [i.content for i in all_tweets]
y_train = [i.sentiment for i in all_tweets]

# %%
t = text.Transformer('vicgalle/xlm-roberta-large-xnli-anli')
trn = t.preprocess_train(x_train, y_train)
model = t.get_classifier()
learner = ktrain.get_learner(model, train_data=trn, batch_size=6)
# Out:
# preprocessing train...
# language: id
# train sequence lengths:
# 	mean : 13
# 	95percentile : 20
# 	99percentile : 24
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False

# %%
learner.fit_onecycle(2e-7, 1)
# Out:
# begin training using onecycle policy with max lr of 2e-07...
# 2522/2522 [==============================] - 1707s 676ms/step - loss: 0.9187 - accuracy: 0.5442

# %% [markdown]
# # ===================================================

# %% [markdown]
# # Mission Control - Prediction

# %% [markdown]
# ### Loading Prediction Data

# %%
actual_labels_dict = dict()
with open(r'data/test/test_labels_hinglish.txt','r') as fp:
    line = fp.readline()
    while True:
        line = fp.readline()
        if not line:
            break
        actual_labels_dict[line.strip().split(',')[0]] = line.strip().split(',')[1]
all_test_tweets = readFile(r'data/test/Hindi_test_unalbelled_conll_updated.txt',test_data=True)
for i in all_test_tweets:
    i.sentiment = actual_labels_dict[i.uid]

# %% [markdown]
# ### Getting the Predictions

# %%
predictor = ktrain.get_predictor(learner.model, preproc=t)
predictions = []
for i in all_test_tweets:
    predictions.append(predictor.predict(i.content))

# %% [markdown]
# ### The Results

# %%
actual_num = []
for i in all_test_tweets:
    if i.sentiment == "neutral":
        actual_num.append(0)
    elif i.sentiment == "positive":
        actual_num.append(1)
    elif i.sentiment == "negative":
        actual_num.append(2)
predictions_num = []
for i in predictions:
    if i == "neutral":
        predictions_num.append(0)
    elif i == "positive":
        predictions_num.append(1)
    elif i == "negative":
        predictions_num.append(2)

show_results(actual_num, predictions_num)

# Calculate accuracy
accuracy = (correct_predictions / total_examples) * 100

print("Accuracy:", accuracy, "%")
# Out:
# F1 Score:  0.607033801007357
#
# Accuracy: 57.266666666666666 %

# %% [markdown]
# # Analysing Incorrect Results

# %%
for i in range(len(actual_num)):
    if (actual_num[i]!=predictions_num[i]):
        print("Actual:",all_test_tweets[i].sentiment)
        print("Predicted:",predictions[i][0][0][9:])
        print(all_test_tweets[i].content)
        print("=====================================================================")
# Out:
# Streaming output truncated to the last 5000 lines.
# Actual: negative
# Predicted:
# rt pk how chamche kya haal chamcho bada chilla lahul gandhi bn gaya pm ÿ ˜ ÿ ˜ ÿ ˜ ÿ ˜ ÿ ˜ ÿ ˜ ÿ ˜ ÿ ˜ ÿ ˜
# =====================================================================
# Actual: negative
# Predicted:
# rt chirayu educ system chutiye h ghanta achi job milegi bc faltu subjects alag languag padhayi
# =====================================================================
# Actual: positive
# Predicted:
# µ hit ¯ fit bhojpuri song super hit shishir panti thakur
# =====================================================================
# Actual: positive
# Predicted:
# bhai h mgr pas h bjp achut bna h nfrat bhir dilon khuda
# =====================================================================
# Actual: neutral
# Predicted:
# rt faysalquraishi aaj sheri thank farhanqis love meet kamranjillani adnanjillani irfanmw adilmurad nomanmaso
# =====================================================================
# Actual: positive
# Predicted:
# what awesom end epic drama ranjharanjhakardi we miss iamimranashraf bhola scre
# =====================================================================
# Actual: negative
# Predicted:
# rt mehraj ali k humamalik zakirkhan imrankhanpti present aapki deklo shameless beggar india fastest grow â major â
# =====================================================================
# Actual: positive
# Predicted:
# zorawar danvir chauhan hindi rajbhasha rashtrabhasa kripya wi padhai
# =====================================================================
# Actual: negative
# Predicted:
# jojojoheeley old ben kay philmoorhouse mrjamesob so abl evid claim but ™ you made
# =====================================================================
# Actual: neutral
# Predicted:
# rt mylondi ÿž ¶ wev got beatast prize grab ÿž wev team friend vimto give chanc win pa
# =====================================================================
# Actual: neutral
# Predicted:
# kavita sharma congress kuj v krle fayda jo hindutva teer bjp chlaya hjab todd nik
# =====================================================================
# Actual: negative
# Predicted:
# sab free dete sir bheekh maang jeeyege
# =====================================================================
# Actual: negative
# Predicted:
# dalitsamajindia thewirehindi rss k thee isliye kyuki veerta kaam kartey
# =====================================================================
# Actual: positive
# Predicted:
# rt dretekdem one thing i ™ realiz ™ forc nobodi see bigger see got nobodi els imma ju
# =====================================================================
# Actual: neutral
# Predicted:
# nehasinghjazz fauj gener free hand par limit aage politician ki responsibil
# =====================================================================
# Actual: neutral
# Predicted:
# jaisal amit jatinnigam aslam bandvi thesamirabbas narendramodi bhai janta karayi w
# =====================================================================
# Actual: negative
# Predicted:
# modiji mota bhai run banate puri pakistan ki team chutiyo world cup jeetna
# =====================================================================
# Actual: positive
# Predicted:
# rt radha singh gussa h bura hoo par sachai gussa niklwaata h right wrong shalin
# =====================================================================
# Actual: neutral
# Predicted:
# majorpoonia mamataoffici jai shri ram mark respect bhagwaan ram narendramodi
# =====================================================================
# Actual: negative
# Predicted:
# gajendr sacchi debat bhagne congressi punjipati yonke ishare nachanewale media wa
# =====================================================================
# Actual: neutral
# Predicted:
# rt bhumika ghutan lagi paas jate rooth usey manaate azhar iqbal
# =====================================================================
# Actual: positive
# Predicted:
# naqvisahab best dua result tou dunia wi onke dar tou buss onh ataat chahye bulawa
# =====================================================================
# Actual: positive
# Predicted:
# rt b raja pakkiri funfil movi from thi june pakkirifromjune daystogopakkiri dhanushkraja kenscottfakir fakiroff
# =====================================================================
# Actual: positive
# Predicted:
# vinaymadsfan b a d m a n in films cheez baith jati like director vision great scene good
# =====================================================================
# Actual: neutral
# Predicted:
# za waseem ym maryamnsharif prince bhai investig offic naam zaroor cap sardar ga ÿ ˜ ÿ ˜ ÿ ˜ ÿ ˜
# =====================================================================
# Actual: positive
# Predicted:
# hsn shah nahi noor aag pakistan team laga first match wi kya khele wah
# =====================================================================
# Actual: neutral
# Predicted:
# someon ask to dhruv rathee election khatam ho gye ab kya karoge dhruv rathee aas pass ke area me jcb ki khuda
# =====================================================================
# Actual: neutral
# Predicted:
# drpratiksha ra bies mera badla dr
# =====================================================================
# Actual: positive
# Predicted:
# itsyourkhaleesi yaar awesom would never good true
# =====================================================================
# Actual: negative
# Predicted:
# yoursbadgirl madarchod khada aur draw room
# =====================================================================
# Actual: positive
# Predicted:
# rt deespeak i proud call first show actor ï  ÿ ™  ÿ  » lautne tamanna waapsi yakeen mazhab ha
# =====================================================================
# Actual: positive
# Predicted:
# vinayakantrai indiatoday ajitarticl desh ki samsyaye modi givt k liye chalkenge nahi samasyao k liye ham log challange h hsmar
# =====================================================================
# Actual: negative
# Predicted:
# narendramodi sardanarohit sir repli famou person hamare sepoy ko repli
# =====================================================================
# Actual: neutral
# Predicted:
# iveenakhan achi jobmil gyi h tumhen veena pti media cell men mpa mna tumhen ga bigboss ki
# =====================================================================
# Actual: negative
# Predicted:
# modisarkaar satya naas india longer world fastestgrow economi
# =====================================================================
# Actual: neutral
# Predicted:
# kuch baaten seedha dil par lagti hain jaise you use ÿ ’ ¯ data neeru
# =====================================================================
# Actual: negative
# Predicted:
# ashoswai ndtv yeh bc mc nikla
# =====================================================================
# Actual: negative
# Predicted:
# rt buzzartz everytim mamatafrustr act bengali song bhoot amaar poot petni amaar jhi ram lakkhan sathe ache korb ama
# =====================================================================
# Actual: negative
# Predicted:
# zakirkhan jshilanjanm bhaijaan brainwash youth educ job chang onc articl a
# =====================================================================
# Actual: neutral
# Predicted:
# reema sahanii antin ki band baji haiamit shah ji home minist banane vajah
# =====================================================================
# Actual: negative
# Predicted:
# rahulgandhi mr rahul save constitut apko family sarkar chalani h nation chala skte ap
# =====================================================================
# Actual: positive
# Predicted:
# gappistanradio bhai hard luck today all best next season
# =====================================================================
# Actual: negative
# Predicted:
# khanumarfa manakgupta adityarajkaul ye jabra bhakt fake news dikha dikha journal ko
# =====================================================================
# Actual: negative
# Predicted:
# ofkat panditrahul sipahi confus fuse atma kud pichwade kida pahle auranjeb aulad ÿ ˜ ÿ ˜ ÿ ˜
# =====================================================================
# Actual: negative
# Predicted:
# anjanaomkashyap congress introl aa bhaj dava bhari pad hahahaa mo
# =====================================================================
# Actual: neutral
# Predicted:
# aur mechan k laundo made easy materi chiye mujhse sampark
# =====================================================================
# Actual: positive
# Predicted:
# rt jem art cookierun i love dino sour
# =====================================================================
# Actual: positive
# Predicted:
# even enem disappear kisi buri bhawna lagta past life kucc pending ab lena
# =====================================================================
# Actual: neutral
# Predicted:
# rt springawakefest ÿž ‰ ticket giveaway ÿž ‰ win free pair wristband to enter ˜ ‘ rt post ˜ ‘ tag friend see late check ou
# =====================================================================
# Actual: negative
# Predicted:
# saurabh mlagk modi bad make ppl work n sweat aur tajinderbagga tumhe aap samaj maaf
# =====================================================================
# Actual: negative
# Predicted:
# srk wolverin ye ye dikhao chutiyon poster releas chaatna shuru
# =====================================================================
# Actual: neutral
# Predicted:
# kiigall pr lgda cultur v jruri ta modrn pone chkr youth wrong track te
# =====================================================================
# Actual: neutral
# Predicted:
# sambit patrag narendramodi snehils duniya ko sbhi btane vkt gya h sir desh
# =====================================================================
# Actual: neutral
# Predicted:
# rt navu insan good night bappu msg gurmeetramrahim ji waliooo sari rehmt brsaa deo niddkk pyar machde aw bappu ji onna
# =====================================================================
# Actual: neutral
# Predicted:
# ab halat hame visa milega bc cc caatul saukarna anshul m
# =====================================================================
# Actual: negative
# Predicted:
# doctoratlarg a ki dhamki saas saari femin nikal jaayegi
# =====================================================================
# Actual: neutral
# Predicted:
# kingcryptoindia wais trader paida h mindset h paas
# =====================================================================
# Actual: negative
# Predicted:
# delhi villag metro citi bijlipanishiksha modi ji india gao phucha pollut ha
# =====================================================================
# Actual: neutral
# Predicted:
# dalsaakkian anoop khiladi taran adarsh rohitjswl kamaalrkhan you wrong bharat go bigg
# =====================================================================
# Actual: positive
# Predicted:
# pm khan pm deputi speaker best asad qaiser aha
# =====================================================================
# Actual: negative
# Predicted:
# chetan bhagat you need go your harm mind indian cant distinguish good fiction book save life
# =====================================================================
# Actual: negative
# Predicted:
# shruttitandon mamataoffici didi mental hospit bhej rahoge anyway jai shree ram ÿ ™  mamataoffici
# =====================================================================
# Actual: negative
# Predicted:
# rt mibgaidhani ippatel acche sanskar bade aavashyak dnyan sanskaroka sambandh siddha common
# =====================================================================
# Actual: positive
# Predicted:
# vinitatiwari oh age gyi ache hamesha hmare ï  sad
# =====================================================================
# Actual: negative
# Predicted:
# ssenapati piyushgoy eastcoastrail naveen odisha chutiya kaat te bc khane nme pr khana rs dete
# =====================================================================
# Actual: positive
# Predicted:
# hartrocsa fufa hit ÿ ’ ƒÿ  ÿ ’ ƒÿ 
# =====================================================================
# Actual: negative
# Predicted:
# surendervarma jarariya ye fahm h pas teri etni ookat ni h hme dra de
# =====================================================================
# Actual: negative
# Predicted:
# mandy bht expect thi us film isiliye dimag maa bhn gyi race tozero expect ke dekhne gya
# =====================================================================
# Actual: positive
# Predicted:
# waqt kabhi jaise nahi dushro rulane khud roye honge kab
# =====================================================================
# Actual: positive
# Predicted:
# it ™ realli refresh see igbo becom igbo centric day goe who would tho
# =====================================================================
# Actual: positive
# Predicted:
# rahul gandhi aane garibon bhavishya
# =====================================================================
# Actual: neutral
# Predicted:
# apne hindustan mei may janme bachche naam narendra modi pariwar bhagwan ba
# =====================================================================
# Actual: negative
# Predicted:
# tiwarimanoj sonamjain haan voter ne gali khane kam kiya pragya giriraj amit smriti anpadh
# =====================================================================
# Actual: positive
# Predicted:
# shakti epi saumyaspeak ss saumya aapki ladai aapke khadi hoon phir chahe dun
# =====================================================================
# Actual: negative
# Predicted:
# muhammadtalib ziddy zoya vitchandra abe kate aulaad sala ishawr multisemen h maa m
# =====================================================================
# Actual: neutral
# Predicted:
# ankita docmoonkim sonpapadbt himjazz bt twt vyshuuu mere face pta zrur himjazz kaam ÿ ˜ ‚
# =====================================================================
# Actual: negative
# Predicted:
# ravibis ashutoshb chutiya dikho aandha bhakt
# =====================================================================
# Actual: neutral
# Predicted:
# anjanaomkashyap jaise chautha satambh claim krne wle log opposit teekhe sawal krne wle ar
# =====================================================================
# Actual: neutral
# Predicted:
# kumkum agar chunaav bahiskar karege mp rajasthan or chatisgad sasan chodna padega
# =====================================================================
# Actual: negative
# Predicted:
# anil vidyaraj narendramodi chutiye bevkuf ban gye tumko tameez h ladki baat
# =====================================================================
# Actual: negative
# Predicted:
# kunalkamra abe chutiye bolna sikh vi fail kya pta desh chalta h abe comedy kosis tere b achi h
# =====================================================================
# Actual: neutral
# Predicted:
# p m narend modi bharat congress mukat bna rahul congress gandhi mukat bna narendramodi bjpsanjaybhatia
# =====================================================================
# Actual: negative
# Predicted:
# ashusmile lunch break darte last bench jaane aajkal fb backbench bolt arre bc ideal st
# =====================================================================
# Actual: neutral
# Predicted:
# rt prithvirajfan prateik dayweekaa ani hindu upper cast baat saari stori fake aur plant nikalti from
# =====================================================================
# Actual: neutral
# Predicted:
# ish bhandari rg not wear cloth ek jo pyjama kurta chaddi nahi woh bina kapde ke bi reht
# =====================================================================
# Actual: negative
# Predicted:
# ravigar anili bjp thekedar rss in bade leader daamaad mulle h ÿ ˜ ‚ bahar
# =====================================================================
# Actual: neutral
# Predicted:
# muglikar bhau alia bank bjp join
# =====================================================================
# Actual: neutral
# Predicted:
# asadowaisi bhaijaan he pray ible one eye close symbol dajjal
# =====================================================================
# Actual: negative
# Predicted:
# arvindkejriwal therez page facebooksa krjriwalthat page done damag u full antimodi
# =====================================================================
# Actual: negative
# Predicted:
# acharyapramodk rahul pm isliye samay rahul baba paas sarkar chalane dimag man
# =====================================================================
# Actual: neutral
# Predicted:
# drkumarvishwa priy dil ajeej kaviraj aps madad bade mudde aapse baat chahte
# =====================================================================
# Actual: positive
# Predicted:
# great effort connect us although ™ week fee like ™ known ™ year ÿºÿº eek cheesi
# =====================================================================
# Actual: neutral
# Predicted:
# o itssumiyya i mole freckl wrist ya pata bartan dho dho ker ghissa lia ÿ ˜ ‚
# =====================================================================
# Actual: positive
# Predicted:
# rahulgandhi rahul ji khushi baath month keliye parti spokesperson ko tv debat rehne n
# =====================================================================
# Actual: positive
# Predicted:
# india vote stabil strength electr ujjwala yojana dbt swachchh bharat growth bett
# =====================================================================
# Actual: neutral
# Predicted:
# chouhanshivraj apko central govt mean minister bnaya jaye umeed apke pita ji dukh rip ÿ ˜ “
# =====================================================================
# Actual: positive
# Predicted:
# rt kenyan mojishortbabaa jabidii music the winner regga ragga song of the year china jabidii music grooveawards
# =====================================================================
# Actual: negative
# Predicted:
# iamssjangle hai saala self acclaim critic joh humse panga
# =====================================================================
# Actual: neutral
# Predicted:
# ÿ ‘  youtub ve maahi kesari cute love story akshay kumar parineeti latest hindi song samarth swarup
# =====================================================================
# Actual: neutral
# Predicted:
# khan cricketworldcup fir makeup suit pahnaya hero tumne video dikhakar sabit
# =====================================================================
# Actual: positive
# Predicted:
# ye raaten ye mausam nadi ka kinara enjoy play beauti retro song destin wed mumba
# =====================================================================
# Actual: neutral
# Predicted:
# weuttarpradesh lkopolic uppolice par gaadi likha homeguard jhoot
# =====================================================================
# Actual: negative
# Predicted:
# anooshaviews lagta ik aulad sharam what u give u life allah duniya
# =====================================================================
# Actual: negative
# Predicted:
# hamaih abdulsrkian trickbolli fake news laana bnd kr munnaa warna kl pta chle baap fake ÿ £ ÿ £ ÿ £
# =====================================================================
# Actual: neutral
# Predicted:
# dunya hotay i love cricket i like cricket mera world cup int
# =====================================================================
# Actual: positive
# Predicted:
# ek modi sarkar banne desh wasiyo hardik subhkamnaye
# =====================================================================
# Actual: negative
# Predicted:
# kewalroshan kapilsharmak sonytv teri gaand lund saley sindhi bhadwe ÿ ˜ pichwade pakistan madarcho
# =====================================================================
# Actual: neutral
# Predicted:
# shweta nn b desh log happi jb janta bhukha mrna chahti sarkar galti
# =====================================================================
# Actual: positive
# Predicted:
# rt investindia socialimpact jab bharat padega tab india badhega investindia continu touch live social impact p
# =====================================================================
# Actual: negative
# Predicted:
# aliyahabib kuti lgti tou zalalat better
# =====================================================================
# Actual: neutral
# Predicted:
# mixedraita salim miyaa mullah best cross ÿµÿÿ ½ ÿ · ÿ • ˜ ªï  alway go vote right pmnonstop aga
# =====================================================================
# Actual: negative
# Predicted:
# irshadbhatti main kahta hon k bu jitni b fake polit hain parda farma jayein zarorat
# =====================================================================
# Actual: neutral
# Predicted:
# all one super entertain promo back back promo dhee dheejodi jabardasth extrajabardasth povepora
# =====================================================================
# Actual: negative
# Predicted:
# rt arnold bharatiya janata party does not believe in hindu religionpatriotismindian constitut secularism bjp doe not f
# =====================================================================
# Actual: negative
# Predicted:
# rt cshamik isupportpriyankasharma your time mamataoffici aapka time
# =====================================================================
# Actual: neutral
# Predicted:
# rt medisisinterna ndtv kaanto taaj h abki baar sarkar mm kamayi arthvyavastha chuki h parai bazar haath khe
# =====================================================================
# Actual: neutral
# Predicted:
# in exam hall me friend bhai scale he ignor nahi me pencil he nahi m
# =====================================================================
# Actual: negative
# Predicted:
# sudhirchaudhary ye saale desh khilaap modi ji khilaap bolne sudhar enko desh
# =====================================================================
# Actual: negative
# Predicted:
# aartic ye news ka detail pta karleti bss daalna
# =====================================================================
# Actual: negative
# Predicted:
# devsing baesquets rahi bat ran adi free bi dalu gobar chu dalta chuki ÿ ˜ ‰ ÿ ˜ ‰
# =====================================================================
# Actual: neutral
# Predicted:
# innov earth kill kr kosis mobil phone laptop nast emergeni police lucknow bhejo
# =====================================================================
# Actual: neutral
# Predicted:
# bat galat rubikaliyaquat ji kahni
# =====================================================================
# Actual: positive
# Predicted:
# rt diksha dheere dheere zindagi aana my current favorit song yehrishteyhainpyaarke its sooth n
# =====================================================================
# Actual: neutral
# Predicted:
# may allah bless us strong imaan taqwa pieti pure heart good manner ÿœ ya allah give eye
# =====================================================================
# Actual: negative
# Predicted:
# vote adhikar uski ma baap chhin legi
# =====================================================================
# Actual: neutral
# Predicted:
# arynewsud remov zartajgulwazir serv famili husband job delan bhe aurat hath pao mar
# =====================================================================
# Actual: neutral
# Predicted:
# inspirationofmillion gurmeetramrahim guru ji saint desh aage badhne logo
# =====================================================================
# Actual: positive
# Predicted:
# iamsaidharamtej always thought load talent time unde bhayya time pattina sare script choosi teesko all best
# =====================================================================
# Actual: negative
# Predicted:
# sakshijoshii twitterindia verifi sakshijoshii vari krane h jagah dimak lgati h
# =====================================================================
# Actual: negative
# Predicted:
# pak vs west hum shirminda hai pak team buri halat zamdar imran khan galat polici aur interfair karna
# =====================================================================
# Actual: negative
# Predicted:
# some peopl social media thekedar rw ideolog they issu certif rw bhagwan bachaye logo
# =====================================================================
# Actual: negative
# Predicted:
# hum kisiko sunna ab congress ki arrog unko bhari padi ab bhuka
# =====================================================================
# Actual: neutral
# Predicted:
# rt angshguds sowe did it again congratul india congratul narendramodi ji congratul amitshah ji congratul
# =====================================================================
# Actual: negative
# Predicted:
# warsisoni sale gosh pta kr lete h mgr n pta kase mre haram khor h sale sb musalman
# =====================================================================
# Actual: neutral
# Predicted:
# mian hanjra sadiakhan fawadchaudhri hahahaha chalein lein ÿ ˜ ‚ ÿ ˜ ‚ btw
# =====================================================================
# Actual: negative
# Predicted:
# hvgoenka in india logo baithne jagah milti library kholenge public transport
# =====================================================================
# Actual: neutral
# Predicted:
# rt kashmirolog aaj yaad bohat aarahi
# =====================================================================
# Actual: negative
# Predicted:
# bbhuttozardari tri hard go jail end you cant save yourselfabba phopho
# =====================================================================
# Actual: neutral
# Predicted:
# nazonazish alhamdulilah hon and perfum kabhe perfume ki advertis bna ÿ ˜ ›
# =====================================================================
# Actual: negative
# Predicted:
# aamir aishash majorgauravarya iaf mcc tum anpadh pakistanio samaj ayega ÿ ˜ ‚
# =====================================================================
# Actual: negative
# Predicted:
# rssurjewala khujliwala sorry say i angri congress
# =====================================================================
# Actual: negative
# Predicted:
# callm yourdad joker k superspy captainforever nooobmaster syede saibkaskar tujy sister joke fursat khusree
# =====================================================================
# Actual: positive
# Predicted:
# smritiirani bilkul jis haar kaam choda darshata ka
# =====================================================================
# Actual: neutral
# Predicted:
# awai hun tayyabarizwan tharak raab mahluk tarif ÿ ˜ ‚ ÿ ˜ ‚
# =====================================================================
# Actual: negative
# Predicted:
# bc time internet hansney drama loug omg look laugh how
# =====================================================================
# Actual: neutral
# Predicted:
# rt nimra khan look sexi ÿ ˜ ­ ÿ ˜  ÿ ” wajih taseer aka bilal abba bilalabbasonjeetopakistan bilalabbas khan
# =====================================================================
# Actual: negative
# Predicted:
# vikasbha vikas ji itni undbhakti ni h fake video viral kr image gober bekar ap h
# =====================================================================
# Actual: negative
# Predicted:
# pankhuripathak incindia media govern wapis aayi media fair govern chuki
# =====================================================================
# Actual: positive
# Predicted:
# itx halloween soo beauti indian jal rhay dhek
# =====================================================================
# Actual: neutral
# Predicted:
# fan moral what wc nation anthem fan b pretti much got repeat finger cross team india cup
# =====================================================================
# Actual: neutral
# Predicted:
# i found awesom record aawaz deke hamein bulao smule
# =====================================================================
# Actual: negative
# Predicted:
# rt shubhamgarg rssurjewala incindia ab congress pas bolne rah gya h kisi spokesperson bheje debate muh ch
# =====================================================================
# Actual: negative
# Predicted:
# breakup hurt maa taklif verypain ÿ ˜ ”
# =====================================================================
# Actual: negative
# Predicted:
# congress useless spokesperson jobless jaayenge congress decid boycott media longer period
# =====================================================================
# Actual: negative
# Predicted:
# siasatpk kutay bacha even disgrac kutah compar loyal creatur
# =====================================================================
# Actual: negative
# Predicted:
# hardikchauhan tum mindset bootlicking aadat kyoin chodate congress dub
# =====================================================================
# Actual: negative
# Predicted:
# rahulgandhi desh aazad congressi gandhi pariwar gulami bhoole jo mahila bin
# =====================================================================
# Actual: negative
# Predicted:
# newsup ye sub chor h sarkar badli karmchari vhi h
# =====================================================================
# Actual: negative
# Predicted:
# just wanna take moment breath without stress fuck exam mein stress exam result ka stre
# =====================================================================
# Actual: positive
# Predicted:
# pc sarangi ji cant imagin better choic live saint partap chand sarangi includ modiji
# =====================================================================
# Actual: positive
# Predicted:
# par jitega au ÿ ˜ ‚ rt imsahilbhalla this go interest cwc afghanistan beat pakistan
# =====================================================================
# Actual: positive
# Predicted:
# atut v pavitra sombandh karya viswas nirnay ram ban v janhitkari bahut bahut bhadhayiyan sh
# =====================================================================
# Actual: neutral
# Predicted:
# fawadchaudhri sardarzadasahib fawad ch apnay bugz kina nikaal ulama khelaf logo chand
# =====================================================================
# Actual: negative
# Predicted:
# besharmo ap log pehli rozay raknay wajha sy england daora taky rozay rakhay shame pak team
# =====================================================================
# Actual: positive
# Predicted:
# tamashbeen musangh patna digha ka malda aam duniya aam dudhiya malda muqabla
# =====================================================================
# Actual: negative
# Predicted:
# alkhurrampk dushman pta ni k pakistan bigar saken jahil khootttii awam pakistan ly doben giii
# =====================================================================
# Actual: neutral
# Predicted:
# maejunee rolandsdalo meet new friend pls dont forget heheh
# =====================================================================
# Actual: positive
# Predicted:
# alkit patel kapilsharmak krushna kas i wish rishta se whosunilgrov k ban jaye comedy duniya aapki jaye
# =====================================================================
# Actual: neutral
# Predicted:
# insaaaashii pledgeagainstcorrupt thousand follow taken pledg accept bribe nd offer motiv s
# =====================================================================
# Actual: negative
# Predicted:
# sanjay tu duniya bada chutiya saale jamin gaddha khod samaa usme bhala insaniya
# =====================================================================
# Actual: negative
# Predicted:
# incindia good decis bann tv debat faltu bakwas h wha tv walo news milti h party naam kharab h
# =====================================================================
# Actual: positive
# Predicted:
# shayarimran inshallah kabhi na kabhi jeetoge dua moradabad galat kiya aapke
# =====================================================================
# Actual: negative
# Predicted:
# mediacellppp bbhuttozardari pehlay corrupt baap product order fiqar ker billo sahiba
# =====================================================================
# Actual: positive
# Predicted:
# bap sunoo chanda lotu hun tad itx awari oyeduaasheikh itxduakhan kazmi shahkar aayeshaaw oye aisha good one ÿ £ ÿ £ ÿ £
# =====================================================================
# Actual: neutral
# Predicted:
# rssurjewala sir ji peopl india modi ji aap behalf bole
# =====================================================================
# Actual: negative
# Predicted:
# anjanaomkashyap teri bhrastachaari badi bhrastachaari maha bikau fixer
# =====================================================================
# Actual: neutral
# Predicted:
# rt rajesh weets haqdaar banna asaan kaamyabi equat set ab raja beta raja bnega supertrail
# =====================================================================
# Actual: positive
# Predicted:
# yeshajethva deepakmundey arvindkejriw yeshjethva kaan sirji janta pagal bjp v
# =====================================================================
# Actual: negative
# Predicted:
# rs mushir sir manakgupta jaise logo ki pichwade me drar pad jaati hai sarkar se sawal karne me s
# =====================================================================
# Actual: negative
# Predicted:
# rt sahilrockk manakgupta kyon acche jante modi crimin h aur north wale brainwashed aatanki h rs
# =====================================================================
# Actual: neutral
# Predicted:
# drjitendrasingh increasessccglvac increasessccglvac pmoindia narendramodi sir aapko modi ji
# =====================================================================
# Actual: negative
# Predicted:
# vikasbha so typic bhakths godi media fake video dil bharta
# =====================================================================
# Actual: neutral
# Predicted:
# surya iamumairmalik espncricinfo oh apni maa behen pelney walon jana humey bari
# =====================================================================
# Actual: positive
# Predicted:
# rt mustafvi sab sy pehly cheez janna wajib ilme nafey lazim nafs aeybon jaanna mqiitika
# =====================================================================
# Actual: negative
# Predicted:
# asim meer what agenda ptm apko ubi yhi samj ni arahe ptm maqsad kia ptm accept pa
# =====================================================================
# Actual: positive
# Predicted:
# kahdo dushmno jra smbhl jay watan serhad dehshat felay kyonki modi ji tufan uthega
# =====================================================================
# Actual: positive
# Predicted:
# jeetu nail role kota factori day habit trick best part ï  tvf kotafactori theviralfev
# =====================================================================
# Actual: negative
# Predicted:
# panjabiap siddiquiamana raghibmohammadi ek chutiya maha chutiya musalman khate h
# =====================================================================
# Actual: positive
# Predicted:
# rt onetiponehand ek nara ek naam jai shri ram jai shri ram deal
# =====================================================================
# Actual: neutral
# Predicted:
# size naapney shoq bohat dr saheba awaeen mard paas khaas tor ilaaj karaney jatey mai
# =====================================================================
# Actual: negative
# Predicted:
# rt sashik oathceremoni modi main narendra damodardas modi ishwar shapath leke kehta hoon desh kejriwal main bac
# =====================================================================
# Actual: negative
# Predicted:
# krickr pakistan team phir maa chudi jaayege aap aana nottingham ÿ £ ÿ ˜ ‚
# =====================================================================
# Actual: negative
# Predicted:
# zeenewshindi mainten dega metro bus party barbad rahega delhi chor nah
# =====================================================================
# Actual: positive
# Predicted:
# gauravkapur sdhawan imro oaktreesport what episod love gauravkapur ÿ ‘  and best part th
# =====================================================================
# Actual: positive
# Predicted:
# prateek bhomia atalji vjah e ayodhya raita faila kaante saaf krke jameen samtal ba
# =====================================================================
# Actual: positive
# Predicted:
# rt billiontwits going coza timi dakolo tweet realis appallingli religi naiv nigerian mind a man
# =====================================================================
# Actual: negative
# Predicted:
# souravs what meant say chutiya bsdk hmesha beizzati krata ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚
# =====================================================================
# Actual: neutral
# Predicted:
# trulygaleej massakk rogerisgod chilluvandu ajaw chinizyaada present fun im happi time travel
# =====================================================================
# Actual: negative
# Predicted:
# manpree hr mania rangoli a lo hadh yaar hrithik fan likhna bi
# =====================================================================
# Actual: neutral
# Predicted:
# kgf singh pass inn sb chalane remote h ÿ ˜ ‚ ÿ ˜ ‚
# =====================================================================
# Actual: negative
# Predicted:
# kumarkunalmedia ch logo even use ledder
# =====================================================================
# Actual: negative
# Predicted:
# shame anjana om kashyap kanhaiya kumar lakh vote basil kiya lekin tumne words bhi governt ke bolne himmat
# =====================================================================
# Actual: positive
# Predicted:
# oooh good giggl i love confid ride brought barrelrac
# =====================================================================
# Actual: negative
# Predicted:
# msisodia are handsome sudhar dilli chunav bacha public paise uda educ jho
# =====================================================================
# Actual: negative
# Predicted:
# sinchan sinceresayar dilwala aukaat kya saale ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ kahin ceremoni mein canadian aam ata ÿ ˜ ‚ ÿÿ
# =====================================================================
# Actual: negative
# Predicted:
# kal bhaut loss motion k case aa lagata modi doobara pm baante hajaam raaha bjpindia
# =====================================================================
# Actual: neutral
# Predicted:
# mamataoffici jai shri ram bhagwan thum sadbuddi de complet bhakti day prabhu shri ram
# =====================================================================
# Actual: negative
# Predicted:
# silvershad trueindologyliv ye majak twitter unlock acc phir suspend wtf ÿ ˜ ¡ ÿ ˜ ¡
# =====================================================================
# Actual: positive
# Predicted:
# rt wahiduddinkhan the best dua make lailatul qadr spiritoframadan
# =====================================================================
# Actual: negative
# Predicted:
# godofhumour ye land mark black mark delhi history ÿ ˜ ‘ ram bharose delhi waqt stateh
# =====================================================================
# Actual: positive
# Predicted:
# sneakerfil zsneakerheadz yooo i don ™ like jordan s part cleannn
# =====================================================================
# Actual: neutral
# Predicted:
# ye pagalpan hstf pakda h paper stf kregii ye sale nikamme loog bhrasht gov
# =====================================================================
# Actual: positive
# Predicted:
# gautamgambhir modi ji wajh jit mili sapne bhuliyega warna atishi apki mar lene
# =====================================================================
# Actual: neutral
# Predicted:
# aap jsise kamjor aur lachar logo modi ji amit ji jaroor yojana lyenge fikra kisiko marn
# =====================================================================
# Actual: negative
# Predicted:
# madhvi srbachchan im sad bad news bohat dukh laga man udas gya plz bhagwan
# =====================================================================
# Actual: positive
# Predicted:
# pcsarangi ramlal bjpindia kirenrijiju bjpodisha badhai ji
# =====================================================================
# Actual: negative
# Predicted:
# bbcurdu sahsanraza tum tezi dikhao ge news nashr chahte pakistan id
# =====================================================================
# Actual: neutral
# Predicted:
# shumaliwaziristan boya me fauj ki gari pr firing or bomb hamla sala sipahi amil shah shahe mah k duran jawan shaheedzakhmiispr
# =====================================================================
# Actual: negative
# Predicted:
# saale pataa gayaa hogaa bachungaa police fande
# =====================================================================
# Actual: neutral
# Predicted:
# rt sangydass kescokanpur aj din bher kaushalpuri lght bahut crisi h kya problem h kripya bataye per saber
# =====================================================================
# Actual: neutral
# Predicted:
# shabazgil shabazgil muqadma ni chye bs bndy sy sare aam maafi mangni gi agi polic offic fasila maaf kre badla ly
# =====================================================================
# Actual: positive
# Predicted:
# rjaadhi yesterday saw mariyan dhanush best actor town
# =====================================================================
# Actual: neutral
# Predicted:
# ankitlal mssirsa sunane bjp troll fire kaphi kharcha gya nahi
# =====================================================================
# Actual: positive
# Predicted:
# maryamnsharif aameen sum ameen thank u much side bestest aapi world cant explai
# =====================================================================
# Actual: neutral
# Predicted:
# narendramodi ji nay minor horaha bhaye eak chale yani dekhawa modi ji nazar aaraha
# =====================================================================
# Actual: negative
# Predicted:
# rssurjewala incindia it good everi time spokesperson say humaare rahul ji dikkana makkahna maa aakh
# =====================================================================
# Actual: negative
# Predicted:
# incer anurag ye saale dukan band karwa they biggest deshdrohi india
# =====================================================================
# Actual: negative
# Predicted:
# sagarikaghose debate baccha goos aunti run
# =====================================================================
# Actual: neutral
# Predicted:
# ansaraabbasi ilzam lga hay sabit gya apni adalton pr aitbar hay kia suprem judici council isiliye bnai gai
# =====================================================================
# Actual: neutral
# Predicted:
# urduvoa ek tha voa voa cia funding ly ker ptm ka tarjuman ban gya hy jo riyasat se takraye ga pash pa
# =====================================================================
# Actual: positive
# Predicted:
# sri vinayaka benne gulkan a year old famou shop thi best place get delici butter banana
# =====================================================================
# Actual: negative
# Predicted:
# they say breakup hurt me lode chinti kata
# =====================================================================
# Actual: negative
# Predicted:
# ghummans murad saeed donkey b batana chahea ta drone attack ki ijazt esk abu musharaf bhagore ti
# =====================================================================
# Actual: positive
# Predicted:
# iamrana no one accus kis qadar garan subah baidari hum pyaar haan neend tumhain pyaari
# =====================================================================
# Actual: neutral
# Predicted:
# itni dil arzu mai apnay mulk kai liyai jawan gul ban kai khil jawan ÿœ pakistan teray l
# =====================================================================
# Actual: neutral
# Predicted:
# tbmini phale gaana sunao gha justin bieber ka ÿ ˜ fer bhoojpuri song ÿ ˜
# =====================================================================
# Actual: neutral
# Predicted:
# ranaayyub hanji vote vote madam marji dalen democraci
# =====================================================================
# Actual: negative
# Predicted:
# ecdalal ko joota maro sunil arora kutta pilla hai
# =====================================================================
# Actual: negative
# Predicted:
# khan jannat sonamjain suhana speak wsayya lol ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ gussa bahan bewakuf insan teri nazar
# =====================================================================
# Actual: positive
# Predicted:
# seven lust i pick yet mayb later year i free time actual complete game
# =====================================================================
# Actual: neutral
# Predicted:
# please love mankind
# =====================================================================
# Actual: positive
# Predicted:
# rt finnryan theyr heeere yes ÿ ˜ ­ ÿ ˜ ‚ hahahaha ™ good though lot peep post ufojoe said ™ gonna p
# =====================================================================
# Actual: negative
# Predicted:
# ye lady kejriwal attention hadh gir jayegi udhar chutiya modi naam leke
# =====================================================================
# Actual: negative
# Predicted:
# gunmast g arvindkejriw msisodia bahut bhaag din
# =====================================================================
# Actual: positive
# Predicted:
# varundhawan review tahirakashyap aparshaktikhurana ™ kudiyeni track say ˜ what beauti song ™
# =====================================================================
# Actual: negative
# Predicted:
# rssurjewala toofan mein taash ka ghar nahi banta rone bigada hua muqaddar banta haar fakir
# =====================================================================
# Actual: negative
# Predicted:
# zakiani natsecjeff indopac info their plural singular aur madrassa chaap hamein english padhaate ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚
# =====================================================================
# Actual: neutral
# Predicted:
# nasir yousafza jehangiriahmad pak armi harket nhen kr skti dekhai essa ga p
# =====================================================================
# Actual: positive
# Predicted:
# the optim fam unreal hogaye match hosakta
# =====================================================================
# Actual: neutral
# Predicted:
# aajtak well done sir ÿ ‘  lekin kash aap congress kaam pahele nehru ji itani
# =====================================================================
# Actual: neutral
# Predicted:
# tarekfatah so world cup thrash team ™ perform sum kurta pajama gayab
# =====================================================================
# Actual: neutral
# Predicted:
# drharshvardhan bjpindia narendramodi amitshah bjpdelhi dr sahab aapki jai bhut sukhad anubhav aapko
# =====================================================================
# Actual: neutral
# Predicted:
# meeqathashmi hislopia saar intellectu gyan ground change la ha saar pseudo ha zakir naik k fan ha
# =====================================================================
# Actual: positive
# Predicted:
# rt cmrlee final got round watching ˜ nae pasaran ™ bbciplay what great programm i idea stori give
# =====================================================================
# Actual: positive
# Predicted:
# friesbeforguyx notif style chang hogya direct tweet share ka option better hogya menu better agya
# =====================================================================
# Actual: neutral
# Predicted:
# rt alinoor jo pant ramadan loose thein fit gyi alhumdulillah
# =====================================================================
# Actual: negative
# Predicted:
# aajtak mahatma gandhi desh hein wo azadi desh hein but godse jabse bjp ayi tabse henc
# =====================================================================
# Actual: positive
# Predicted:
# drkumarvishwa shekharkapur azmishabana officialurmila veri beauti movi favorit song tujhse naraaz
# =====================================================================
# Actual: positive
# Predicted:
# smoicl everytim i see floor i hume wood ÿ ˜ œ good memori
# =====================================================================
# Actual: negative
# Predicted:
# split ink rozenameh sorry gee akhbaar walay thoray say paindu ye paper towel walay shenanigan aatay
# =====================================================================
# Actual: negative
# Predicted:
# thatbeardguy shame u search chahiya student ka lia scheme ÿ ˜ ‚
# =====================================================================
# Actual: positive
# Predicted:
# sherryontopp jalte buj bjp bewafa andhere yu gustakhiya h tumne
# =====================================================================
# Actual: neutral
# Predicted:
# india realli need better technic batsmen ajinkya rahane middl order england migh
# =====================================================================
# Actual: negative
# Predicted:
# drkumarvishwas inka bhaav khatam kuch mila bjp aap bahar rakkha ag
# =====================================================================
# Actual: positive
# Predicted:
# rgvzoomin tarak thank sir ji tarak polit entri latega admee koti milega admee b
# =====================================================================
# Actual: positive
# Predicted:
# rt cevansbitch this scene wouldve been so much better with this song omfg
# =====================================================================
# Actual: neutral
# Predicted:
# yes he is papa nomura bless
# =====================================================================
# Actual: neutral
# Predicted:
# poulocruelo sorry like retweet ÿ ˜ ‚ modi naam bawajood oye aunty aukaat kbhi mt bhulna
# =====================================================================
# Actual: neutral
# Predicted:
# sekci bunnytherabbit sk aeee jhotaaa ÿ ‘ » ramzan ma jhoot ÿ ˜
# =====================================================================
# Actual: neutral
# Predicted:
# bikrambarman majorgauravarya tarekfatah un teri jali jali teri or hn spell chor tu bar
# =====================================================================
# Actual: positive
# Predicted:
# nostalgicgaffar varunssakshi ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ mazaak krta hu serious mtt
# =====================================================================
# Actual: negative
# Predicted:
# ...
# rt sidk syedasimwaqar asadowaisi aimim news channel ka boycott sahab bjp prasar madhyam ban chuke
# =====================================================================
# Actual: negative
# Predicted:
# bbchindi aub evm ghus dekhoge jab bjp jeeta poora major matlab vote daala
# =====================================================================
# Actual: negative
# Predicted:
# dhruv rathee bprerna abe dalle utni class pass ni paas phd degre neem patta
# =====================================================================
# Actual: negative
# Predicted:
# dekhna es chutiye gand fatt ti h ahahahah maa chuda salle
# =====================================================================
# Actual: neutral
# Predicted:
# jsdl offici raghuraj bhadri rbyb offici yahe hy rajputana jay jansatta jay raghuraj ÿ ™  ÿ  » ÿ ™  ÿ  » ÿ ™  ÿ  » ÿ ™  ÿ  » ÿ ™  ÿ  »
# =====================================================================
# Actual: neutral
# Predicted:
# engr sohail a iamdraciel yahan bat view ki isk baray jannay iski bakwas su
# =====================================================================
# Actual: neutral
# Predicted:
# indiatoday raghav chadha u r go get maximum vote fr aap at place aap posit po
# =====================================================================
# Actual: neutral
# Predicted:
# pmoindia narendramodi shree narendr modi ji nd time pm bnne pr hardik badhai
# =====================================================================
# Actual: neutral
# Predicted:
# jarariya ha bsp ne mp vidhansabha aapko tkt sardanarohit
# =====================================================================
# Actual: negative
# Predicted:
# rt ceptainamerica men r stupid agre bt woman love complet idiot u ÿ ˜ ÿ ˜ ‘
# =====================================================================
# Actual: negative
# Predicted:
# studyiq ÿ ˜ ¡ logo zindagi india map dheka kashmir hissa kider tumahri boho
# =====================================================================
# Actual: positive
# Predicted:
# fanofhamza bhout faisla bol channel new talent ai ga alreadi give audit act
# =====================================================================
# Actual: neutral
# Predicted:
# migunamiguna koinangejeff citizentvkenya i miss migunai watch weep
# =====================================================================
# Actual: neutral
# Predicted:
# pak cricket team ek dollor ke barabar runs bhi nahi bana saki ÿ ˜ ‚ pakvswi
# =====================================================================
# Actual: neutral
# Predicted:
# sayousafzaipti ye aesa kry ga bilawal butto zardari khoon ye ajj tk baat fa
# =====================================================================
# Actual: positive
# Predicted:
# rt nishasi aankho khawaise chehre hate kyysonvootwithpaniasmanan laghateparth niti taylor bbc
# =====================================================================
# Actual: negative
# Predicted:
# pankhuripathak haa brhman apradh obc st bare brahman apma
# =====================================================================
# Actual: neutral
# Predicted:
# rt karamji dailydsshashtag derasachasauda gurmeetramrahim welfarebydssvolunt guru ji prerna pr chalte garib priwar
# =====================================================================
# Actual: negative
# Predicted:
# shame zartaj gul she ideolog worker just pathet abi climat chang wali speech blunder bahr thi
# =====================================================================
# Actual: neutral
# Predicted:
# it like cheat day i studi today i feel guilti realli
# =====================================================================
# Actual: negative
# Predicted:
# icc ye bhosdike bhadwa h lund h bolne english only bolega well play bhag bhosdike
# =====================================================================
# Actual: neutral
# Predicted:
# rt rjaniverma hpy brother day shyopiverma god bless sry bhul gyi wish krna ÿ ˜ ÿ ˜
# =====================================================================
# Actual: neutral
# Predicted:
# nishmennnair beautiful word one fav song
# =====================================================================
# Actual: neutral
# Predicted:
# aajtak pankajjainclick taaze taaze joote pade hein deshdrohi kejriwal team loksabha pr ye
# =====================================================================
# Actual: neutral
# Predicted:
# tejasvi surya sir bihar love you great job bjp continu we
# =====================================================================
# Actual: positive
# Predicted:
# insanneeru thegiftofeducation derasachasauda do great deed hat gurmeetramrahim ji
# =====================================================================
# Actual: neutral
# Predicted:
# must song aaye aap ka intezar tha vijaypath august
# =====================================================================
# Actual: neutral
# Predicted:
# rt mondocoool sorry sorry sorry
# =====================================================================
# Actual: positive
# Predicted:
# aparnadixit report card rahul salon seat badhat kya kam ji bechare bekar pa
# =====================================================================
# Actual: neutral
# Predicted:
# kamaalrkhan sir aapke survey hisaab rahul ji modi ji kaante takkar aapke durvery aa
# =====================================================================
# Actual: negative
# Predicted:
# srksharri bc paunga oppon bohut harami team h bc ÿ ˜ ‚
# =====================================================================
# Actual: neutral
# Predicted:
# rt my prospect ek shayer manzil milti jinke sapno jaan pankh hauslon udaan ha
# =====================================================================
# Actual: positive
# Predicted:
# ratlamdrm gmwrli westernrli im in chittorgarh bahut hi shandar safai stn per hai beautiful paint stn parisa
# =====================================================================
# Actual: positive
# Predicted:
# aishwaryajumna desh perm chaheya hindu muslim exampl militari forc mazhab
# =====================================================================
# Actual: neutral
# Predicted:
# saraahahahaha sak meni nhin kya topic
# =====================================================================
# Actual: negative
# Predicted:
# azkhawaja kyun harami hahaha krra team haal is bar coach zinda aayega vapas
# =====================================================================
# Actual: negative
# Predicted:
# nationfirst drrizwanahmed a chutiya nikla suhar aulad
# =====================================================================
# Actual: neutral
# Predicted:
# ashirkh pakimuslimah dexxxtur bhai kiyo fake news phela game khelta asi jagha asi game ÿ ˜ £
# =====================================================================
# Actual: negative
# Predicted:
# picsnart haan osi champion trophi ke sar pakistani cricket kharab ker bilkul afridi ne
# =====================================================================
# Actual: negative
# Predicted:
# sabse bada chutiya adult page k advertis video kat te bc promis video
# =====================================================================
# Actual: negative
# Predicted:
# paulwhitehous cheer mate you may comedi geniu still spur w ker lol top geezer ynwa
# =====================================================================
# Actual: positive
# Predicted:
# rt moizahmed zainifatima hehe ku zaini behen apki waja hogye
# =====================================================================
# Actual: neutral
# Predicted:
# jm scindia ji mein incindia samarthank appki dhukhi jaroor jab hosh sabhala aap
# =====================================================================
# Actual: positive
# Predicted:
# cricbuzz virat queen ho rabba umr pighli imam aisi zid kara deedar e mauka mauka mauka mauka mauka
# =====================================================================
# Actual: negative
# Predicted:
# anjalir kishorebourasi sherryontopp he better niyat ur feku pm ÿ ˜ „
# =====================================================================
# Actual: negative
# Predicted:
# dear best friend tumhari jagha dil uski block list h sudhar jaao bsdkk
# =====================================================================
# Actual: negative
# Predicted:
# pun starr alogicalindi ye sale america uksa india hamla
# =====================================================================
# Actual: positive
# Predicted:
# rt aliraza trust allah hell eas difficulti inshaallah ÿ ˜ š ù „ ûœù „ ûƒøù „ ù ‚ ø ¯ ø ± tahirulqadri tahirulqadriur
# =====================================================================
# Actual: positive
# Predicted:
# therealpcb sarfaraza masoom logo mulaqaaat no aik sri languag nhe smiling kaam chalayaa hy
# =====================================================================
# Actual: neutral
# Predicted:
# bhar jao tweet log interact karrte bass v aab mission unfollow karrna padega ÿ ˜ 
# =====================================================================
# Actual: positive
# Predicted:
# rt knc talent thi icc world cup celebr spirit cricket truli global anthem togeth ÿ   way o way o ÿ   featuri
# =====================================================================
# Actual: neutral
# Predicted:
# khuram mushaimm cuteipiesani em queen go away yrr junejonoorey bee baba bakht sunoo chanda exactli
# =====================================================================
# Actual: neutral
# Predicted:
# malickpakistani siasatpk yes i agre realiti take big step enough enough ab
# =====================================================================
# Actual: neutral
# Predicted:
# bahir beth bhonkty ir bakwas krty tmhara bap phd holder parha likha admi h k corrupt krni wako b
# =====================================================================
# Actual: negative
# Predicted:
# sanjayazadsln pura election fake bhaiya
# =====================================================================
# Actual: negative
# Predicted:
# rt kalpesh drharkar laxmibi hindu sanskruti raksha valo jhute aropo fasaya wesupportpunalek
# =====================================================================
# Actual: negative
# Predicted:
# itz faiz pcstinkerbel sale chutiye update rehta ye criminal buddhe bharat team h
# =====================================================================
# Actual: negative
# Predicted:
# rt avnijesh irfantahir main hindi likhta andu pahle tl check abhi naya
# =====================================================================
# Actual: positive
# Predicted:
# im jay are meko disha patni genelia ileana dcruz ye sbb achhi ÿ ˜ ‚
# =====================================================================
# Actual: neutral
# Predicted:
# anonym gupta but lesbian nhi h n bina jiya jaaye ÿ ˜ ž
# =====================================================================
# Actual: neutral
# Predicted:
# sanjaymanjrekar wc main pakistan nain phele match windi hara wicket pakistan champion
# =====================================================================
# Actual: negative
# Predicted:
# in baccho kunan poshpara k malum pakistan sirf jhoot failya bina soche smjhe man
# =====================================================================
# Actual: neutral
# Predicted:
# vaishali patil ha azadi ladai congress haath h nehru angrejo aurto chhodta bechare
# =====================================================================
# Actual: negative
# Predicted:
# akash khiladi prince of thug itssohailkhan akshaykumar itsbhushankumar bc kutta look actor waja
# =====================================================================
# Actual: neutral
# Predicted:
# ariffazmanshah still awak bro haha selamat hari raya advanc sanjay haha
# =====================================================================
# Actual: neutral
# Predicted:
# narendramodi mani sherri modi ji miri anrodh mehgae km kariye sir ham garib ham gaher
# =====================================================================
# Actual: neutral
# Predicted:
# charanpanjwani hi charan we would sad see go pleas dm us contact number sort thi
# =====================================================================
# Actual: positive
# Predicted:
# chatterjask ha hs ha us hs ha hs ha ha ha rinitiji kalpnaa hasaa padhkar ÿ ˜ ÿ ˜ ÿ ˜ ‚ ÿ £ ÿ ˜ ‚
# =====================================================================
# Actual: negative
# Predicted:
# azharmustafa kunalkamra tum zaiso naam padkar samaj aa kya likhoge ÿ ˜ ‚ ÿ ˜ ‚ jihadi islamicterror
# =====================================================================
# Actual: positive
# Predicted:
# secretofposit gurmeetramrahim guru ji bachan simran aapki ander tamam galat soach ko
# =====================================================================
# Actual: negative
# Predicted:
# mayavatiji sachchai sweekaar lijiye jantaa chaahati aapko pradhanmantri roop dekhana aa
# =====================================================================
# Actual: positive
# Predicted:
# herwhitesila bich first saddl stomp ground dont u slander ur art love give us
# =====================================================================
# Actual: positive
# Predicted:
# rt tkssfan weekend ki badhai kon deta yaar ÿ ” ÿ ˜ ‚ ÿ ˜ ‚ this wa best ÿ ˜  ÿ ˜ ‚ thekapilsharmashow kapilsharmak rajivthakur haanjichandan
# =====================================================================
# Actual: negative
# Predicted:
# cmshehbaz return money bitch mf bsdk wapiss aa pakistan bahir beth k tweet kr rha hai
# =====================================================================
# Actual: neutral
# Predicted:
# rt tomtomato studi face care evil riyasat kissi izzat mehfoiz nahi
# =====================================================================
# Actual: negative
# Predicted:
# teko problem hijab problem bjp bhakto mazhab neeji cheezo tang ada
# =====================================================================
# Actual: negative
# Predicted:
# ineedja kadeeja oh shat i hope i make instal schedul first
# =====================================================================
# Actual: positive
# Predicted:
# rt amtouristerin jeetegi humari team can share men blue need win trophi one hindi word comment
# =====================================================================
# Actual: negative
# Predicted:
# darshanajardosh smritiiranioffc smritiirani very good think yahe bachoo koo sikna shame
# =====================================================================
# Actual: positive
# Predicted:
# sarfarazahm qoomi labaas izat day kr pakistaniyo sar fakhar uncha kr pouri qoom pakistan ki
# =====================================================================
# Actual: negative
# Predicted:
# balwant gowkilleralpha sadiakhattak husainhaqqani kutta mar gya gand fatti convert kutte salveri product ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚
# =====================================================================
# Actual: negative
# Predicted:
# abdullah mar coolfunnytshirt madarchod saale bhadve wire
# =====================================================================
# Actual: positive
# Predicted:
# joke sunne mann rehndo tweet joke h ÿ ™ ƒÿ £ tweet joke ni h
# =====================================================================
# Actual: negative
# Predicted:
# myogiadityanath yogi ji desh chahta h kanun haanth n jab gau rakshak naam susasa
# =====================================================================
# Actual: negative
# Predicted:
# just go hell ÿ ˜ agr petrol › ½ ï  price sy problem khreedo bakwas bnd kr lo senseless ÿ ®
# =====================================================================
# Actual: positive
# Predicted:
# ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ ÿ ˜ ‚ modi ji dil h bar jitoge nare
# =====================================================================
# Actual: positive
# Predicted:
# narendramodi pradhanmantri ji baar bharat pradhan mantri shapath lene badhai shu
# =====================================================================
# Actual: neutral
# Predicted:
# ÿ ™  ÿ ™  ÿ ™  da realest thank put track cant wait next one soon ÿ ™
# =====================================================================
# Actual: neutral
# Predicted:
# rt nimra khan fahad bhaiii give us bilal abba we cant wait anymor bilalabbasonjeetopakistan bilalabbas khan fahadmustafa
# =====================================================================
# Actual: neutral
# Predicted:
# rt fralaliciouxx tbh bad side say horribl bad
# =====================================================================

# %% [markdown]
# # ===================================================

# %% [markdown]
# ### Creating Submission File

# %%
import zipfile
import os

with open('answer.txt',"w") as fp:
    fp.write("Uid,Sentiment\n")
    for i in range(len(predictions_num)):
        if predictions_num[i]==0:
            if i==(len(predictions_num)-1):
                fp.write(all_test_tweets[i].uid+",neutral")
            else:
                fp.write(all_test_tweets[i].uid+",neutral\n")
        elif predictions_num[i]==1:
            if i==(len(predictions_num)-1):
                fp.write(all_test_tweets[i].uid+",positive")
            else:
                fp.write(all_test_tweets[i].uid+",positive\n")
        elif predictions_num[i]==2:
            if i==(len(predictions_num)-1):
                fp.write(all_test_tweets[i].uid+",negative")
            else:
                fp.write(all_test_tweets[i].uid+",negative\n")

class ZipUtilities:
    def toZip(self, file, filename):
        zip_file = zipfile.ZipFile(filename, 'w')
        if os.path.isfile(file):
            zip_file.write(file)
        else:
            self.addFolderToZip(zip_file, file)
        zip_file.close()

    def addFolderToZip(self, zip_file, folder):
        for file in os.listdir(folder):
            full_path = os.path.join(folder, file)
            if os.path.isfile(full_path):
                print( 'File added: ' + str(full_path))
                zip_file.write(full_path)
            elif os.path.isdir(full_path):
                print( 'Entering folder: ' + str(full_path))
                self.addFolderToZip(zip_file, full_path)

utilities = ZipUtilities()
filename = 'answer.zip'
directory = 'answer.txt'
utilities.toZip(directory, filename)
