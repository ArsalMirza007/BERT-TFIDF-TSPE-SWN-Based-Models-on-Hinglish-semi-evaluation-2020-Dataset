# %%
# !unzip 'data.zip'
# Out:
# Archive:  data.zip
#   inflating: data/hinglish_stopwords.txt
#    creating: data/test/
#   inflating: data/test/Hindi_test_unalbelled_conll_updated.txt
#   inflating: data/test/test_labels_hinglish.txt
#    creating: data/train/
#   inflating: data/train/dev_3k_split_conll.txt
#   inflating: data/train/train_14k_split_conll.txt
#   inflating: data/train/train_conll.txt
#   inflating: data/train/trial_conll.txt

# %%
# !pip install tensorflow
# !pip install transformers
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.13)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 70.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import string
import nltk
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dropout, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import f1_score, confusion_matrix, classification_report, precision_score, recall_score, accuracy_score

nltk.download('stopwords')

class Tweet:
    def __init__(self):
        self.uid = None
        self.content = ''
        self.sentiment = ''

def cleanTweet(tweet):
    tweet.content = re.sub(r'\_', '', tweet.content)  # remove underscores
    tweet.content = re.sub(r'…', '', tweet.content)  # remove elipses/dots
    tweet.content = re.sub(r'\.', '', tweet.content)  # remove elipses/dots
    tweet.content = re.sub(r'^RT[\s]+', '', tweet.content)  # remove RT
    tweet.content = re.sub(
        "[#@©àâ€¦¥°¤ð¹ÿœ¾¨‡†§‹²¿¸ˆ]", '', tweet.content
    )  # remove weird symbols
    tweet.content = tweet.content.split("http")[0].split('https')[0]  # remove http/https
    tweet.content = ''.join([i for i in tweet.content if not i.isdigit()])  # remove digits
    tweet.content = ''.join([word for word in tweet.content if word not in string.punctuation])  # remove punctuations
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet.content = tokenizer.tokenize(tweet.content)
    tweet.content = ' '.join([i for i in tweet.content])  # convert to string
    return tweet

def load_stop_words():
    stopwords_english = stopwords.words('english')
    stopwords_hinglish = []
    with open('data/hinglish_stopwords.txt', 'r') as fp:
        while True:
            line = fp.readline()
            if not line:
                break
            stopwords_hinglish.append(line.strip())
    return stopwords_english, stopwords_hinglish

def readFile(filename, test_data=False):
    stemmer_english = PorterStemmer()
    stopwords_english, _ = load_stop_words()
    all_tweets = []
    with open(filename, 'r', encoding="utf8") as fp:
        tweet = Tweet()
        last_one = False
        while True:
            line = fp.readline()
            if not line:
                last_one = True
            if len(line.split()) > 1 or last_one:
                if last_one or line.split()[0] == 'meta':
                    if len(tweet.content) > 0 or last_one:
                        all_tweets.append(cleanTweet(tweet))
                        if last_one:
                            break
                        tweet = Tweet()
                    tweet.uid = line.split()[1]
                    tweet.sentiment = line.split()[2] if not test_data else None
                else:
                    if line.split()[1] == "Eng":
                        if line.split()[0] not in stopwords_english:
                            tweet.content += stemmer_english.stem(line.split()[0]) + " "
                    elif line.split()[1] == "Hin":
                        tweet.content += line.split()[0] + " "
                    else:
                        tweet.content += line.split()[0] + " "
    return all_tweets

def plot_confusion_matrix(cm, title='Confusion Matrix', cmap=plt.cm.Greens):
    import itertools
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    classes = ['neutral', 'positive', 'negative']
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

def show_results(y_test, y_pred):
    classification_rep = classification_report(y_test, y_pred, labels=[0, 1, 2])
    print("Classification Report:")
    print(classification_rep)

    f1 = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    support = np.sum(confusion_matrix(y_test, y_pred, labels=[0, 1, 2]), axis=1)
    accuracy = accuracy_score(y_test, y_pred)

    print("F1 Score: ", f1)
    print("Precision: ", precision)
    print("Recall: ", recall)
    print("Support: ", support)
    print("Accuracy: ", accuracy)

    cnf_matrix = confusion_matrix(y_test, y_pred, labels=[0, 1, 2])
    plot_confusion_matrix(cnf_matrix)


all_tweets = readFile(r'data/train/train_conll.txt')

x_train = [i.content for i in all_tweets]
y_train = [i.sentiment for i in all_tweets]

# Preprocess the data
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train)

# Convert text data to sequences
x_train_seq = tokenizer.texts_to_sequences(x_train)
x_test_seq = tokenizer.texts_to_sequences(x_test)

# Convert text data to TF-IDF representations
vectorizer = TfidfVectorizer(max_features=1000)
x_train_tfidf = vectorizer.fit_transform(x_train).toarray()
x_test_tfidf = vectorizer.transform(x_test).toarray()

# Encode labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Convert labels to categorical format
y_train_categorical = to_categorical(y_train_encoded)
y_test_categorical = to_categorical(y_test_encoded)

# Build the model
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=x_train_tfidf.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(units=3, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train_tfidf, y_train_categorical, epochs=120, batch_size=32, validation_data=(x_test_tfidf, y_test_categorical))

# Plot accuracy
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
y_pred = np.argmax(model.predict(x_test_tfidf), axis=-1)
y_test_labels = np.argmax(y_test_categorical, axis=-1)
loss, accuracy = model.evaluate(x_test_tfidf, y_test_categorical)
print("Loss: ", loss)
print("Accuracy: ", accuracy)

# Calculate precision, recall, and accuracy
classification_rep = classification_report(y_test_labels, y_pred, labels=[0, 1, 2])
print("Classification Report:")
print(classification_rep)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Epoch 1/150
# 379/379 [==============================] - 2s 3ms/step - loss: 0.9772 - accuracy: 0.5121 - val_loss: 0.8717 - val_accuracy: 0.5857
# Epoch 2/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.8335 - accuracy: 0.6179 - val_loss: 0.8378 - val_accuracy: 0.6003
# Epoch 3/150
# 379/379 [==============================] - 1s 4ms/step - loss: 0.7900 - accuracy: 0.6449 - val_loss: 0.8355 - val_accuracy: 0.5913
# Epoch 4/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.7644 - accuracy: 0.6568 - val_loss: 0.8405 - val_accuracy: 0.5930
# Epoch 5/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.7452 - accuracy: 0.6741 - val_loss: 0.8434 - val_accuracy: 0.5920
# Epoch 6/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.7269 - accuracy: 0.6771 - val_loss: 0.8544 - val_accuracy: 0.5907
# Epoch 7/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.7102 - accuracy: 0.6894 - val_loss: 0.8612 - val_accuracy: 0.5937
# Epoch 8/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.6990 - accuracy: 0.6939 - val_loss: 0.8669 - val_accuracy: 0.5900
# Epoch 9/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.6845 - accuracy: 0.7016 - val_loss: 0.8704 - val_accuracy: 0.5877
# Epoch 10/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.6701 - accuracy: 0.7094 - val_loss: 0.8805 - val_accuracy: 0.5923
# Epoch 11/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.6585 - accuracy: 0.7184 - val_loss: 0.8885 - val_accuracy: 0.5907
# Epoch 12/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.6453 - accuracy: 0.7277 - val_loss: 0.8927 - val_accuracy: 0.5887
# Epoch 13/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.6285 - accuracy: 0.7336 - val_loss: 0.9035 - val_accuracy: 0.5933
# Epoch 14/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.6162 - accuracy: 0.7436 - val_loss: 0.9115 - val_accuracy: 0.5897
# Epoch 15/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.5996 - accuracy: 0.7534 - val_loss: 0.9225 - val_accuracy: 0.5847
# Epoch 16/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.5876 - accuracy: 0.7593 - val_loss: 0.9322 - val_accuracy: 0.5837
# Epoch 17/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.5775 - accuracy: 0.7626 - val_loss: 0.9391 - val_accuracy: 0.5834
# Epoch 18/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.5578 - accuracy: 0.7757 - val_loss: 0.9438 - val_accuracy: 0.5867
# Epoch 19/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.5427 - accuracy: 0.7829 - val_loss: 0.9619 - val_accuracy: 0.5844
# Epoch 20/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.5302 - accuracy: 0.7864 - val_loss: 0.9678 - val_accuracy: 0.5867
# Epoch 21/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.5195 - accuracy: 0.7922 - val_loss: 0.9803 - val_accuracy: 0.5880
# Epoch 22/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.5040 - accuracy: 0.7996 - val_loss: 0.9858 - val_accuracy: 0.5861
# Epoch 23/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.4922 - accuracy: 0.8064 - val_loss: 1.0046 - val_accuracy: 0.5834
# Epoch 24/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.4771 - accuracy: 0.8164 - val_loss: 1.0096 - val_accuracy: 0.5828
# Epoch 25/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.4714 - accuracy: 0.8181 - val_loss: 1.0243 - val_accuracy: 0.5824
# Epoch 26/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.4555 - accuracy: 0.8215 - val_loss: 1.0359 - val_accuracy: 0.5864
# Epoch 27/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.4410 - accuracy: 0.8322 - val_loss: 1.0515 - val_accuracy: 0.5841
# Epoch 28/150
# 379/379 [==============================] - 1s 4ms/step - loss: 0.4346 - accuracy: 0.8283 - val_loss: 1.0645 - val_accuracy: 0.5791
# Epoch 29/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.4202 - accuracy: 0.8387 - val_loss: 1.0783 - val_accuracy: 0.5798
# Epoch 30/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.4055 - accuracy: 0.8442 - val_loss: 1.0956 - val_accuracy: 0.5824
# Epoch 31/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3988 - accuracy: 0.8461 - val_loss: 1.1091 - val_accuracy: 0.5798
# Epoch 32/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3859 - accuracy: 0.8534 - val_loss: 1.1165 - val_accuracy: 0.5808
# Epoch 33/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3809 - accuracy: 0.8545 - val_loss: 1.1263 - val_accuracy: 0.5765
# Epoch 34/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3680 - accuracy: 0.8589 - val_loss: 1.1416 - val_accuracy: 0.5801
# Epoch 35/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3590 - accuracy: 0.8651 - val_loss: 1.1665 - val_accuracy: 0.5785
# Epoch 36/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3468 - accuracy: 0.8704 - val_loss: 1.1730 - val_accuracy: 0.5758
# Epoch 37/150
# 379/379 [==============================] - 1s 4ms/step - loss: 0.3439 - accuracy: 0.8668 - val_loss: 1.1898 - val_accuracy: 0.5795
# Epoch 38/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.3324 - accuracy: 0.8755 - val_loss: 1.2061 - val_accuracy: 0.5765
# Epoch 39/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.3258 - accuracy: 0.8765 - val_loss: 1.2247 - val_accuracy: 0.5808
# Epoch 40/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3180 - accuracy: 0.8819 - val_loss: 1.2354 - val_accuracy: 0.5785
# Epoch 41/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3184 - accuracy: 0.8790 - val_loss: 1.2456 - val_accuracy: 0.5824
# Epoch 42/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.3054 - accuracy: 0.8842 - val_loss: 1.2623 - val_accuracy: 0.5752
# Epoch 43/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2901 - accuracy: 0.8942 - val_loss: 1.2843 - val_accuracy: 0.5808
# Epoch 44/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2912 - accuracy: 0.8873 - val_loss: 1.2899 - val_accuracy: 0.5771
# Epoch 45/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2839 - accuracy: 0.8946 - val_loss: 1.3048 - val_accuracy: 0.5755
# Epoch 46/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2792 - accuracy: 0.8943 - val_loss: 1.3276 - val_accuracy: 0.5778
# Epoch 47/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2749 - accuracy: 0.8971 - val_loss: 1.3471 - val_accuracy: 0.5755
# Epoch 48/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2693 - accuracy: 0.8997 - val_loss: 1.3693 - val_accuracy: 0.5768
# Epoch 49/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.2627 - accuracy: 0.9019 - val_loss: 1.3915 - val_accuracy: 0.5771
# Epoch 50/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.2599 - accuracy: 0.8996 - val_loss: 1.3981 - val_accuracy: 0.5765
# Epoch 51/150
# 379/379 [==============================] - 1s 4ms/step - loss: 0.2548 - accuracy: 0.9023 - val_loss: 1.4109 - val_accuracy: 0.5715
# Epoch 52/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2475 - accuracy: 0.9078 - val_loss: 1.4348 - val_accuracy: 0.5735
# Epoch 53/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2413 - accuracy: 0.9098 - val_loss: 1.4556 - val_accuracy: 0.5728
# Epoch 54/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2405 - accuracy: 0.9097 - val_loss: 1.4680 - val_accuracy: 0.5682
# Epoch 55/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2378 - accuracy: 0.9104 - val_loss: 1.4836 - val_accuracy: 0.5728
# Epoch 56/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2299 - accuracy: 0.9183 - val_loss: 1.4917 - val_accuracy: 0.5709
# Epoch 57/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2339 - accuracy: 0.9103 - val_loss: 1.5106 - val_accuracy: 0.5748
# Epoch 58/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2223 - accuracy: 0.9178 - val_loss: 1.5273 - val_accuracy: 0.5692
# Epoch 59/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.2192 - accuracy: 0.9185 - val_loss: 1.5443 - val_accuracy: 0.5752
# Epoch 60/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.2218 - accuracy: 0.9153 - val_loss: 1.5624 - val_accuracy: 0.5722
# Epoch 61/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.2107 - accuracy: 0.9226 - val_loss: 1.5784 - val_accuracy: 0.5685
# Epoch 62/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.2125 - accuracy: 0.9195 - val_loss: 1.5935 - val_accuracy: 0.5676
# Epoch 63/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1991 - accuracy: 0.9264 - val_loss: 1.6342 - val_accuracy: 0.5643
# Epoch 64/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1989 - accuracy: 0.9273 - val_loss: 1.6473 - val_accuracy: 0.5682
# Epoch 65/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1973 - accuracy: 0.9259 - val_loss: 1.6605 - val_accuracy: 0.5709
# Epoch 66/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1945 - accuracy: 0.9274 - val_loss: 1.6852 - val_accuracy: 0.5709
# Epoch 67/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1947 - accuracy: 0.9259 - val_loss: 1.6879 - val_accuracy: 0.5702
# Epoch 68/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1977 - accuracy: 0.9237 - val_loss: 1.7283 - val_accuracy: 0.5695
# Epoch 69/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1864 - accuracy: 0.9299 - val_loss: 1.7300 - val_accuracy: 0.5699
# Epoch 70/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1872 - accuracy: 0.9289 - val_loss: 1.7408 - val_accuracy: 0.5652
# Epoch 71/150
# 379/379 [==============================] - 1s 4ms/step - loss: 0.1861 - accuracy: 0.9305 - val_loss: 1.7626 - val_accuracy: 0.5682
# Epoch 72/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1817 - accuracy: 0.9325 - val_loss: 1.7726 - val_accuracy: 0.5738
# Epoch 73/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1793 - accuracy: 0.9349 - val_loss: 1.7931 - val_accuracy: 0.5656
# Epoch 74/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1792 - accuracy: 0.9307 - val_loss: 1.8092 - val_accuracy: 0.5676
# Epoch 75/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1757 - accuracy: 0.9334 - val_loss: 1.8314 - val_accuracy: 0.5705
# Epoch 76/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1736 - accuracy: 0.9356 - val_loss: 1.8226 - val_accuracy: 0.5712
# Epoch 77/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1663 - accuracy: 0.9398 - val_loss: 1.8692 - val_accuracy: 0.5748
# Epoch 78/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1687 - accuracy: 0.9344 - val_loss: 1.8938 - val_accuracy: 0.5692
# Epoch 79/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1745 - accuracy: 0.9304 - val_loss: 1.8896 - val_accuracy: 0.5652
# Epoch 80/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1604 - accuracy: 0.9411 - val_loss: 1.8997 - val_accuracy: 0.5679
# Epoch 81/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1555 - accuracy: 0.9417 - val_loss: 1.9233 - val_accuracy: 0.5682
# Epoch 82/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1675 - accuracy: 0.9364 - val_loss: 1.9415 - val_accuracy: 0.5662
# Epoch 83/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.1579 - accuracy: 0.9399 - val_loss: 1.9522 - val_accuracy: 0.5682
# Epoch 84/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1543 - accuracy: 0.9394 - val_loss: 1.9946 - val_accuracy: 0.5672
# Epoch 85/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1549 - accuracy: 0.9419 - val_loss: 1.9836 - val_accuracy: 0.5712
# Epoch 86/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1521 - accuracy: 0.9427 - val_loss: 2.0011 - val_accuracy: 0.5709
# Epoch 87/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1517 - accuracy: 0.9426 - val_loss: 2.0460 - val_accuracy: 0.5656
# Epoch 88/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1458 - accuracy: 0.9479 - val_loss: 2.0712 - val_accuracy: 0.5659
# Epoch 89/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1497 - accuracy: 0.9427 - val_loss: 2.0512 - val_accuracy: 0.5692
# Epoch 90/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1454 - accuracy: 0.9467 - val_loss: 2.0952 - val_accuracy: 0.5652
# Epoch 91/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1509 - accuracy: 0.9433 - val_loss: 2.0900 - val_accuracy: 0.5695
# Epoch 92/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1435 - accuracy: 0.9445 - val_loss: 2.1056 - val_accuracy: 0.5705
# Epoch 93/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1453 - accuracy: 0.9469 - val_loss: 2.1317 - val_accuracy: 0.5725
# Epoch 94/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1382 - accuracy: 0.9496 - val_loss: 2.1776 - val_accuracy: 0.5702
# Epoch 95/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1379 - accuracy: 0.9495 - val_loss: 2.1871 - val_accuracy: 0.5692
# Epoch 96/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.1377 - accuracy: 0.9474 - val_loss: 2.1976 - val_accuracy: 0.5679
# Epoch 97/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1351 - accuracy: 0.9508 - val_loss: 2.2119 - val_accuracy: 0.5709
# Epoch 98/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1382 - accuracy: 0.9457 - val_loss: 2.2035 - val_accuracy: 0.5722
# Epoch 99/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1379 - accuracy: 0.9485 - val_loss: 2.2353 - val_accuracy: 0.5685
# Epoch 100/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1337 - accuracy: 0.9503 - val_loss: 2.2646 - val_accuracy: 0.5666
# Epoch 101/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1337 - accuracy: 0.9480 - val_loss: 2.2810 - val_accuracy: 0.5738
# Epoch 102/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1347 - accuracy: 0.9505 - val_loss: 2.2737 - val_accuracy: 0.5695
# Epoch 103/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1261 - accuracy: 0.9530 - val_loss: 2.3178 - val_accuracy: 0.5702
# Epoch 104/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1327 - accuracy: 0.9515 - val_loss: 2.3361 - val_accuracy: 0.5689
# Epoch 105/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.1268 - accuracy: 0.9517 - val_loss: 2.3576 - val_accuracy: 0.5745
# Epoch 106/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.1293 - accuracy: 0.9522 - val_loss: 2.3804 - val_accuracy: 0.5633
# Epoch 107/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1280 - accuracy: 0.9513 - val_loss: 2.3772 - val_accuracy: 0.5643
# Epoch 108/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1208 - accuracy: 0.9545 - val_loss: 2.4069 - val_accuracy: 0.5672
# Epoch 109/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1231 - accuracy: 0.9529 - val_loss: 2.4206 - val_accuracy: 0.5656
# Epoch 110/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1213 - accuracy: 0.9539 - val_loss: 2.4374 - val_accuracy: 0.5669
# Epoch 111/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1244 - accuracy: 0.9540 - val_loss: 2.4722 - val_accuracy: 0.5685
# Epoch 112/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1230 - accuracy: 0.9538 - val_loss: 2.4680 - val_accuracy: 0.5662
# Epoch 113/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1168 - accuracy: 0.9547 - val_loss: 2.4893 - val_accuracy: 0.5656
# Epoch 114/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1210 - accuracy: 0.9551 - val_loss: 2.5248 - val_accuracy: 0.5712
# Epoch 115/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1217 - accuracy: 0.9521 - val_loss: 2.5306 - val_accuracy: 0.5616
# Epoch 116/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.1165 - accuracy: 0.9556 - val_loss: 2.5583 - val_accuracy: 0.5666
# Epoch 117/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1183 - accuracy: 0.9545 - val_loss: 2.5788 - val_accuracy: 0.5659
# Epoch 118/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1189 - accuracy: 0.9545 - val_loss: 2.5892 - val_accuracy: 0.5669
# Epoch 119/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1121 - accuracy: 0.9572 - val_loss: 2.5996 - val_accuracy: 0.5652
# Epoch 120/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1151 - accuracy: 0.9541 - val_loss: 2.6247 - val_accuracy: 0.5669
# Epoch 121/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1130 - accuracy: 0.9585 - val_loss: 2.6499 - val_accuracy: 0.5719
# Epoch 122/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1163 - accuracy: 0.9568 - val_loss: 2.6377 - val_accuracy: 0.5728
# Epoch 123/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1147 - accuracy: 0.9562 - val_loss: 2.6928 - val_accuracy: 0.5735
# Epoch 124/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1101 - accuracy: 0.9588 - val_loss: 2.6952 - val_accuracy: 0.5738
# Epoch 125/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1107 - accuracy: 0.9591 - val_loss: 2.7172 - val_accuracy: 0.5735
# Epoch 126/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1085 - accuracy: 0.9575 - val_loss: 2.7180 - val_accuracy: 0.5662
# Epoch 127/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1098 - accuracy: 0.9589 - val_loss: 2.7602 - val_accuracy: 0.5725
# Epoch 128/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1120 - accuracy: 0.9573 - val_loss: 2.7622 - val_accuracy: 0.5742
# Epoch 129/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1059 - accuracy: 0.9595 - val_loss: 2.7851 - val_accuracy: 0.5755
# Epoch 130/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1112 - accuracy: 0.9571 - val_loss: 2.7987 - val_accuracy: 0.5745
# Epoch 131/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1064 - accuracy: 0.9596 - val_loss: 2.8052 - val_accuracy: 0.5752
# Epoch 132/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1045 - accuracy: 0.9594 - val_loss: 2.8318 - val_accuracy: 0.5732
# Epoch 133/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1074 - accuracy: 0.9584 - val_loss: 2.8211 - val_accuracy: 0.5745
# Epoch 134/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1056 - accuracy: 0.9590 - val_loss: 2.8240 - val_accuracy: 0.5702
# Epoch 135/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1076 - accuracy: 0.9587 - val_loss: 2.8919 - val_accuracy: 0.5738
# Epoch 136/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1005 - accuracy: 0.9608 - val_loss: 2.9127 - val_accuracy: 0.5702
# Epoch 137/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.0984 - accuracy: 0.9646 - val_loss: 2.9484 - val_accuracy: 0.5781
# Epoch 138/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1015 - accuracy: 0.9630 - val_loss: 2.9256 - val_accuracy: 0.5768
# Epoch 139/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1031 - accuracy: 0.9600 - val_loss: 2.9524 - val_accuracy: 0.5752
# Epoch 140/150
# 379/379 [==============================] - 2s 5ms/step - loss: 0.1035 - accuracy: 0.9617 - val_loss: 2.9569 - val_accuracy: 0.5765
# Epoch 141/150
# 379/379 [==============================] - 1s 4ms/step - loss: 0.0989 - accuracy: 0.9617 - val_loss: 3.0015 - val_accuracy: 0.5725
# Epoch 142/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1029 - accuracy: 0.9607 - val_loss: 2.9754 - val_accuracy: 0.5738
# Epoch 143/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.0999 - accuracy: 0.9626 - val_loss: 3.0291 - val_accuracy: 0.5738
# Epoch 144/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.1019 - accuracy: 0.9610 - val_loss: 3.0620 - val_accuracy: 0.5732
# Epoch 145/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.0990 - accuracy: 0.9611 - val_loss: 3.0823 - val_accuracy: 0.5761
# Epoch 146/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.0955 - accuracy: 0.9629 - val_loss: 3.0834 - val_accuracy: 0.5752
# Epoch 147/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.0951 - accuracy: 0.9651 - val_loss: 3.0617 - val_accuracy: 0.5722
# Epoch 148/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.0992 - accuracy: 0.9609 - val_loss: 3.1052 - val_accuracy: 0.5722
# Epoch 149/150
# 379/379 [==============================] - 1s 3ms/step - loss: 0.0972 - accuracy: 0.9625 - val_loss: 3.1265 - val_accuracy: 0.5728
# Epoch 150/150
# 379/379 [==============================] - 2s 4ms/step - loss: 0.1005 - accuracy: 0.9613 - val_loss: 3.1201 - val_accuracy: 0.5728
# 95/95 [==============================] - 0s 2ms/step
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1201 - accuracy: 0.5728
# Loss:  3.120082378387451
# Accuracy:  0.572844386100769
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.57       902
#            1       0.50      0.62      0.55      1159
#            2       0.64      0.58      0.61       966
#
#     accuracy                           0.57      3027
#    macro avg       0.59      0.57      0.58      3027
# weighted avg       0.59      0.57      0.57      3027

# %%
# Perform prediction on the test set
y_pred_probs = model.predict(x_test_tfidf)
y_pred = np.argmax(y_pred_probs, axis=1)

# Display evaluation results
show_results(np.argmax(y_test_categorical, axis=1), y_pred)
# Out:
# 95/95 [==============================] - 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.57       902
#            1       0.50      0.62      0.55      1159
#            2       0.64      0.58      0.61       966
#
#     accuracy                           0.57      3027
#    macro avg       0.59      0.57      0.58      3027
# weighted avg       0.59      0.57      0.57      3027
#
# F1 Score:  0.574297431105426
# Precision:  0.587088075480463
# Recall:  0.5728444003964321
# Support:  [ 902 1159  966]
# Accuracy:  0.5728444003964321
